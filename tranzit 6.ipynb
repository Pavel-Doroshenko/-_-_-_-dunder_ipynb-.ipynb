# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavel-Doroshenko/-_-_-_-dunder_ipynb-.ipynb/blob/main/tranzit%206.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.options.display.max_columns = None # полностью отображаем столбцы
warnings.filterwarnings("ignore")
sns.set_style("whitegrid")

# %% [markdown]
# # Новый раздел

# %% [markdown]
# # Новый раздел

# %%
df = pd.read_csv('январь23.csv',sep=';',encoding='windows - 1251')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13850 entries, 0 to 13849
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Номер ЛС ЮЛ                     13850 non-null  object
#  1   Отчетный период                 13850 non-null  int64
#  2   № абонента                      13850 non-null  object
#  3   Количество ТУ                   13850 non-null  int64
#  4   № точки учета                   13850 non-null  object
#  5   Улица                           13850 non-null  object
#  6   Номер дома                      13850 non-null  int64
#  7   Буква дома                      2187 non-null   object
#  8   Корпус                          1 non-null      float64
#  9   Секция                          9 non-null      float64
#  10  Квартира                        13850 non-null  int64
#  11  Помещение                       13850 non-null  object
# ...

# %%
januyry = df.drop(df.columns[[0, 2, 3, 4, 7, 8, 9, 11, 12, 13, 14, 15, 16, 17, 19, 21, 22, 23, 24, 25, 26, 27, 28]], axis = 1)\
            .loc[(df['Улица'] == 'Транзитная') & (df['Номер дома'] == 6)]\
            .rename(columns = {'Отчетный период': 'Отчетный_период', 'Улица':'Улица', 'Номер дома':'Номер_дома', 'Квартира':'Квартира',
                              'НачисленокВт*ч':'Начислено_кВт*ч'})
januyry.head(5)
# Out:
#       Отчетный_период       Улица  Номер_дома  Квартира  \
# 1102           202301  Транзитная           6         3
# 1103           202301  Транзитная           6         3
# 1104           202301  Транзитная           6         3
# 1105           202301  Транзитная           6         3
# 1106           202301  Транзитная           6         3
#
#      Способ формирования начислений  Начислено_кВт*ч
# 1102                             ФП            140.0
# 1103                            NaN            140.0
# 1104                             ФП             51.0
# 1105                            NaN             51.0
# 1106                             ФП              3.0

# %%
df = pd.read_csv('февраль23.csv',sep=';',encoding='windows - 1251')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13795 entries, 0 to 13794
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Номер ЛС ЮЛ                     13795 non-null  object
#  1   Отчетный период                 13795 non-null  int64
#  2   № абонента                      13795 non-null  object
#  3   Количество ТУ                   13795 non-null  int64
#  4   № точки учета                   13795 non-null  object
#  5   Улица                           13795 non-null  object
#  6   Номер дома                      13795 non-null  int64
#  7   Буква дома                      2154 non-null   object
#  8   Корпус                          1 non-null      float64
#  9   Секция                          9 non-null      float64
#  10  Квартира                        13795 non-null  int64
#  11  Помещение                       13795 non-null  object
# ...

# %%
february= df.drop(df.columns[[0, 2, 3, 4, 7, 8, 9, 11, 12, 13, 14, 15, 16, 17, 19, 21, 22, 23, 24, 25, 26, 27, 28]], axis = 1)\
            .loc[(df['Улица'] == 'Транзитная') & (df['Номер дома'] == 6)]\
            .rename(columns = {'Отчетный период': 'Отчетный_период', 'Улица':'Улица', 'Номер дома':'Номер_дома', 'Квартира':'Квартира',
                              'НачисленокВт*ч':'Начислено_кВт*ч'})
february.head(5)
# Out:
#      Отчетный_период       Улица  Номер_дома  Квартира  \
# 813           202302  Транзитная           6        10
# 814           202302  Транзитная           6        10
# 815           202302  Транзитная           6        10
# 816           202302  Транзитная           6        10
# 817           202302  Транзитная           6         1
#
#     Способ формирования начислений  Начислено_кВт*ч
# 813                             ТП            202.0
# 814                            NaN            202.0
# 815                             ФП              9.0
# 816                            NaN              9.0
# 817                             ФП            125.0

# %%
df = pd.read_csv('март 23.csv',sep=';',encoding='windows - 1251')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13376 entries, 0 to 13375
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Номер ЛС ЮЛ                     13376 non-null  object
#  1   Отчетный период                 13376 non-null  int64
#  2   № абонента                      13376 non-null  object
#  3   Количество ТУ                   13376 non-null  int64
#  4   № точки учета                   13376 non-null  object
#  5   Улица                           13376 non-null  object
#  6   Номер дома                      13376 non-null  int64
#  7   Буква дома                      1839 non-null   object
#  8   Корпус                          1 non-null      float64
#  9   Секция                          9 non-null      float64
#  10  Квартира                        13376 non-null  int64
#  11  Помещение                       13376 non-null  object
# ...

# %%
march = df.drop(df.columns[[0, 2, 3, 4, 7, 8, 9, 11, 12, 13, 14, 15, 16, 17, 18, 20, 22, 23, 24, 25, 26, 27, 28,29]], axis = 1)\
            .loc[(df['Улица'] == 'Транзитная') & (df['Номер дома'] == 6)]\
            .rename(columns = {'Отчетный период': 'Отчетный_период', 'Улица':'Улица', 'Номер дома':'Номер_дома', 'Квартира':'Квартира',
                              'НачисленокВт*ч':'Начислено_кВт*ч'})
march.head(5)
# Out:
#       Отчетный_период       Улица  Номер_дома  Квартира  \
# 3765           202303  Транзитная           6        18
# 3766           202303  Транзитная           6        18
# 3767           202303  Транзитная           6        46
# 3768           202303  Транзитная           6        46
# 3769           202303  Транзитная           6        13
#
#      Способ формирования начислений  Начислено_кВт*ч
# 3765                             ФП            209.0
# 3766                            NaN            209.0
# 3767                             РО             91.0
# 3768                            NaN             91.0
# 3769                             ФП            100.0

# %%
march.head(10)
# Out:
#       Отчетный_период       Улица  Номер_дома  Квартира  \
# 3765           202303  Транзитная           6        18
# 3766           202303  Транзитная           6        18
# 3767           202303  Транзитная           6        46
# 3768           202303  Транзитная           6        46
# 3769           202303  Транзитная           6        13
# 3770           202303  Транзитная           6        13
# 8434           202303  Транзитная           6         3
# 8435           202303  Транзитная           6         3
# 8436           202303  Транзитная           6         3
# 8437           202303  Транзитная           6         3
#
#      Способ формирования начислений  Начислено_кВт*ч
# 3765                             ФП            209.0
# 3766                            NaN            209.0
# 3767                             РО             91.0
# 3768                            NaN             91.0
# 3769                             ФП            100.0
# ...

# %%
df = pd.read_csv('апрель23.csv',sep=';',encoding='windows - 1251')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13641 entries, 0 to 13640
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Номер ЛС ЮЛ                     13641 non-null  object
#  1   Отчетный период                 13641 non-null  int64
#  2   № абонента                      13641 non-null  object
#  3   Количество ТУ                   13641 non-null  int64
#  4   № точки учета                   13641 non-null  object
#  5   Улица                           13641 non-null  object
#  6   Номер дома                      13641 non-null  int64
#  7   Буква дома                      1848 non-null   object
#  8   Корпус                          1 non-null      float64
#  9   Секция                          9 non-null      float64
#  10  Квартира                        13641 non-null  int64
#  11  Помещение                       13641 non-null  object
# ...

# %%
april = df.drop(df.columns[[0, 2, 3, 4, 7, 8, 9, 11, 12, 13, 14, 15, 16, 17, 18, 20, 22, 23, 24, 25, 26, 27, 28,29]], axis = 1)\
            .loc[(df['Улица'] == 'Транзитная') & (df['Номер дома'] == 6)]\
            .rename(columns = {'Отчетный период': 'Отчетный_период', 'Улица':'Улица', 'Номер дома':'Номер_дома', 'Квартира':'Квартира',
                              'НачисленокВт*ч':'Начислено_кВт*ч'})
april.head(5)
# Out:
#       Отчетный_период       Улица  Номер_дома  Квартира  \
# 4714           202304  Транзитная           6        18
# 4715           202304  Транзитная           6        18
# 4716           202304  Транзитная           6        46
# 4717           202304  Транзитная           6        46
# 4718           202304  Транзитная           6        13
#
#      Способ формирования начислений  Начислено_кВт*ч
# 4714                             ФП            223.0
# 4715                            NaN            223.0
# 4716                             РО             89.0
# 4717                            NaN             89.0
# 4718                             ФП            100.0

# %%
df = pd.read_csv('май 23.csv',sep=';',encoding='windows - 1251')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13243 entries, 0 to 13242
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Номер ЛС ЮЛ                     13243 non-null  object
#  1   Отчетный период                 13243 non-null  int64
#  2   № абонента                      13243 non-null  object
#  3   Количество ТУ                   13243 non-null  int64
#  4   № точки учета                   13243 non-null  object
#  5   Улица                           13243 non-null  object
#  6   Номер дома                      13243 non-null  int64
#  7   Буква дома                      1833 non-null   object
#  8   Корпус                          1 non-null      float64
#  9   Секция                          11 non-null     float64
#  10  Квартира                        13243 non-null  int64
#  11  Помещение                       13243 non-null  object
# ...

# %%
may = df.drop(df.columns[[0, 2, 3, 4, 7, 8, 9, 11, 12, 13, 14, 15, 16, 17, 18, 20, 22, 23, 24, 25, 26, 27, 28,29]], axis = 1)\
            .loc[(df['Улица'] == 'Транзитная') & (df['Номер дома'] == 6)]\
            .rename(columns = {'Отчетный период': 'Отчетный_период', 'Улица':'Улица', 'Номер дома':'Номер_дома', 'Квартира':'Квартира',
                              'НачисленокВт*ч':'Начислено_кВт*ч'})
may.head(5)
# Out:
#       Отчетный_период       Улица  Номер_дома  Квартира  \
# 3211           202305  Транзитная           6        18
# 3212           202305  Транзитная           6        18
# 3213           202305  Транзитная           6        46
# 3214           202305  Транзитная           6        46
# 3215           202305  Транзитная           6        13
#
#      Способ формирования начислений  Начислено_кВт*ч
# 3211                             ФП            253.0
# 3212                            NaN            253.0
# 3213                             ФП             84.0
# 3214                            NaN             84.0
# 3215                             ФП            100.0

# %%
df = pd.read_csv('июнь23.csv',sep=';',encoding='windows - 1251')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13186 entries, 0 to 13185
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Номер ЛС ЮЛ                     13186 non-null  object
#  1   Отчетный период                 13186 non-null  int64
#  2   № абонента                      13186 non-null  object
#  3   Количество ТУ                   13186 non-null  int64
#  4   № точки учета                   13186 non-null  object
#  5   Улица                           13186 non-null  object
#  6   Номер дома                      13186 non-null  int64
#  7   Буква дома                      1829 non-null   object
#  8   Корпус                          1 non-null      float64
#  9   Секция                          10 non-null     float64
#  10  Квартира                        13186 non-null  int64
#  11  Помещение                       13186 non-null  object
# ...

# %%
junio = df.drop(df.columns[[0, 2, 3, 4, 7, 8, 9, 11, 12, 13, 14, 15, 16, 17, 18, 20, 22, 23, 24, 25, 26, 27, 28,29]], axis = 1)\
            .loc[(df['Улица'] == 'Транзитная') & (df['Номер дома'] == 6)]\
            .rename(columns = {'Отчетный период': 'Отчетный_период', 'Улица':'Улица', 'Номер дома':'Номер_дома', 'Квартира':'Квартира',
                              'Начислено кВт*ч':'Начислено_кВт*ч'})
junio.head(5)
# Out:
#      Отчетный_период       Улица  Номер_дома  Квартира  \
# 942           202306  Транзитная           6         3
# 943           202306  Транзитная           6         3
# 944           202306  Транзитная           6         3
# 945           202306  Транзитная           6         3
# 946           202306  Транзитная           6         3
#
#     Способ формирования начислений  Начислено_кВт*ч
# 942                             ФП            100.0
# 943                            NaN            100.0
# 944                             ФП           -140.0
# 945                            NaN           -140.0
# 946                             ФП              0.0

# %%
df = pd.read_csv('июль23.csv',sep=';',encoding='windows - 1251')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13339 entries, 0 to 13338
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Номер ЛС ЮЛ                     13339 non-null  object
#  1   Отчетный период                 13339 non-null  int64
#  2   № абонента                      13339 non-null  object
#  3   Количество ТУ                   13339 non-null  int64
#  4   № точки учета                   13339 non-null  object
#  5   Улица                           13339 non-null  object
#  6   Номер дома                      13339 non-null  int64
#  7   Буква дома                      1842 non-null   object
#  8   Корпус                          1 non-null      float64
#  9   Секция                          9 non-null      float64
#  10  Квартира                        13339 non-null  int64
#  11  Помещение                       13339 non-null  object
# ...

# %%
julio = df.drop(df.columns[[0, 2, 3, 4, 7, 8, 9, 11, 12, 13, 14, 15, 16, 17, 18, 20, 22, 23, 24, 25, 26, 27, 28,29]], axis = 1)\
            .loc[(df['Улица'] == 'Транзитная') & (df['Номер дома'] == 6)]\
            .rename(columns = {'Отчетный период': 'Отчетный_период', 'Улица':'Улица', 'Номер дома':'Номер_дома', 'Квартира':'Квартира',
                              'Начислено кВт*ч':'Начислено_кВт*ч'})
julio.head(5)
# Out:
#       Отчетный_период       Улица  Номер_дома  Квартира  \
# 2536           202307  Транзитная           6         3
# 2537           202307  Транзитная           6         3
# 2538           202307  Транзитная           6         3
# 2539           202307  Транзитная           6         3
# 2540           202307  Транзитная           6         3
#
#      Способ формирования начислений  Начислено_кВт*ч
# 2536                             ФП             75.0
# 2537                            NaN             75.0
# 2538                             ФП             64.0
# 2539                            NaN             64.0
# 2540                             РО              4.0

# %%
df = pd.read_csv('август23.csv',sep=';',encoding='windows - 1251')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13365 entries, 0 to 13364
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Номер ЛС ЮЛ                     13365 non-null  object
#  1   Отчетный период                 13365 non-null  int64
#  2   № абонента                      13365 non-null  object
#  3   Количество ТУ                   13365 non-null  int64
#  4   № точки учета                   13365 non-null  object
#  5   Улица                           13365 non-null  object
#  6   Номер дома                      13365 non-null  int64
#  7   Буква дома                      1883 non-null   object
#  8   Корпус                          1 non-null      float64
#  9   Секция                          11 non-null     float64
#  10  Квартира                        13365 non-null  int64
#  11  Помещение                       13365 non-null  object
# ...

# %%
agosto = df.drop(df.columns[[0, 2, 3, 4, 7, 8, 9, 11, 12, 13, 14, 15, 16, 17, 18, 20, 22, 23, 24, 25, 26, 27, 28,29]], axis = 1)\
            .loc[(df['Улица'] == 'Транзитная') & (df['Номер дома'] == 6)]\
            .rename(columns = {'Отчетный период': 'Отчетный_период', 'Улица':'Улица', 'Номер дома':'Номер_дома', 'Квартира':'Квартира',
                              'Начислено кВт*ч':'Начислено_кВт*ч'})
agosto.head(5)
# Out:
#       Отчетный_период       Улица  Номер_дома  Квартира  \
# 1344           202308  Транзитная           6        19
# 1345           202308  Транзитная           6        19
# 1398           202308  Транзитная           6         3
# 1399           202308  Транзитная           6         3
# 2337           202308  Транзитная           6        18
#
#      Способ формирования начислений  Начислено_кВт*ч
# 1344                             ФП              4.0
# 1345                            NaN              4.0
# 1398                             РО            163.0
# 1399                            NaN            163.0
# 2337                             ФП            228.0

# %%
df = pd.read_csv('сентябрь23.csv',sep=';',encoding='windows - 1251')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13301 entries, 0 to 13300
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Номер ЛС ЮЛ                     13301 non-null  object
#  1   Отчетный период                 13301 non-null  int64
#  2   № абонента                      13301 non-null  object
#  3   Количество ТУ                   13301 non-null  int64
#  4   № точки учета                   13301 non-null  object
#  5   Улица                           13301 non-null  object
#  6   Номер дома                      13301 non-null  int64
#  7   Буква дома                      1873 non-null   object
#  8   Корпус                          1 non-null      float64
#  9   Секция                          9 non-null      float64
#  10  Квартира                        13301 non-null  int64
#  11  Помещение                       13301 non-null  object
# ...

# %%
septiembre = df.drop(df.columns[[0, 2, 3, 4, 7, 8, 9, 11, 12, 13, 14, 15, 16, 17, 18, 20, 22, 23, 24, 25, 26, 27, 28,29]], axis = 1)\
            .loc[(df['Улица'] == 'Транзитная') & (df['Номер дома'] == 6)]\
            .rename(columns = {'Отчетный период': 'Отчетный_период', 'Улица':'Улица', 'Номер дома':'Номер_дома', 'Квартира':'Квартира',
                              'Начислено кВт*ч':'Начислено_кВт*ч'})
septiembre.head(5)
# Out:
#       Отчетный_период       Улица  Номер_дома  Квартира  \
# 2425           202309  Транзитная           6         4
# 2426           202309  Транзитная           6         4
# 2501           202309  Транзитная           6        29
# 2502           202309  Транзитная           6        29
# 3476           202309  Транзитная           6        18
#
#      Способ формирования начислений  Начислено_кВт*ч
# 2425                             ФП              0.0
# 2426                            NaN              0.0
# 2501                             РО            287.0
# 2502                            NaN            287.0
# 3476                             ФП            226.0

# %%
df = pd.read_csv('октябрь23.csv',sep=';',encoding='windows - 1251')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13474 entries, 0 to 13473
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Номер ЛС ЮЛ                     13474 non-null  object
#  1   Отчетный период                 13474 non-null  int64
#  2   № абонента                      13474 non-null  object
#  3   Количество ТУ                   13474 non-null  int64
#  4   № точки учета                   13474 non-null  object
#  5   Улица                           13474 non-null  object
#  6   Номер дома                      13474 non-null  int64
#  7   Буква дома                      1900 non-null   object
#  8   Корпус                          1 non-null      float64
#  9   Секция                          9 non-null      float64
#  10  Квартира                        13474 non-null  int64
#  11  Помещение                       13474 non-null  object
# ...

# %%
oktubre = df.drop(df.columns[[0, 2, 3, 4, 7, 8, 9, 11, 12, 13, 14, 15, 16, 17, 18, 20, 22, 23, 24, 25, 26, 27, 28,29]], axis = 1)\
            .loc[(df['Улица'] == 'Транзитная') & (df['Номер дома'] == 6)]\
            .rename(columns = {'Отчетный период': 'Отчетный_период', 'Улица':'Улица', 'Номер дома':'Номер_дома', 'Квартира':'Квартира',
                              'Начислено кВт*ч':'Начислено_кВт*ч'})
oktubre.head(5)
# Out:
#       Отчетный_период       Улица  Номер_дома  Квартира  \
# 2120           202310  Транзитная           6        18
# 2121           202310  Транзитная           6        18
# 2122           202310  Транзитная           6        46
# 2123           202310  Транзитная           6        46
# 2124           202310  Транзитная           6        13
#
#      Способ формирования начислений  Начислено_кВт*ч
# 2120                             ФП            194.0
# 2121                            NaN            194.0
# 2122                             ФП            109.0
# 2123                            NaN            109.0
# 2124                             ФП            150.0

# %%
df = pd.read_csv('ноябрь23.csv',sep=';',encoding='windows - 1251')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13439 entries, 0 to 13438
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Номер ЛС ЮЛ                     13439 non-null  object
#  1   Отчетный период                 13439 non-null  int64
#  2   № абонента                      13439 non-null  object
#  3   Количество ТУ                   13439 non-null  int64
#  4   № точки учета                   13439 non-null  object
#  5   Улица                           13439 non-null  object
#  6   Номер дома                      13439 non-null  int64
#  7   Буква дома                      1901 non-null   object
#  8   Корпус                          1 non-null      float64
#  9   Секция                          9 non-null      float64
#  10  Квартира                        13439 non-null  int64
#  11  Помещение                       13439 non-null  object
# ...

# %%
november = df.drop(df.columns[[0, 2, 3, 4, 7, 8, 9, 11, 12, 13, 14, 15, 16, 17, 18, 20, 22, 23, 24, 25, 26, 27, 28,29]], axis = 1)\
            .loc[(df['Улица'] == 'Транзитная') & (df['Номер дома'] == 6)]\
            .rename(columns = {'Отчетный период': 'Отчетный_период', 'Улица':'Улица', 'Номер дома':'Номер_дома', 'Квартира':'Квартира',
                              'Начислено кВт*ч':'Начислено_кВт*ч'})
november.head(5)
# Out:
#       Отчетный_период       Улица  Номер_дома  Квартира  \
# 2429           202311  Транзитная           6        18
# 2430           202311  Транзитная           6        18
# 2431           202311  Транзитная           6        46
# 2432           202311  Транзитная           6        46
# 2433           202311  Транзитная           6        13
#
#      Способ формирования начислений  Начислено_кВт*ч
# 2429                             ФП            301.0
# 2430                            NaN            301.0
# 2431                             ФП             83.0
# 2432                            NaN             83.0
# 2433                             ФП            150.0

# %%
df = pd.read_csv('декабрь23.csv',sep=';',encoding='windows - 1251')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13306 entries, 0 to 13305
# Data columns (total 30 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Номер ЛС ЮЛ                     13306 non-null  object
#  1   Отчетный период                 13306 non-null  int64
#  2   № абонента                      13306 non-null  object
#  3   Количество ТУ                   13306 non-null  int64
#  4   № точки учета                   13306 non-null  object
#  5   Улица                           13306 non-null  object
#  6   Номер дома                      13306 non-null  int64
#  7   Буква дома                      1900 non-null   object
#  8   Корпус                          1 non-null      float64
#  9   Секция                          9 non-null      float64
#  10  Квартира                        13306 non-null  int64
#  11  Помещение                       13306 non-null  object
# ...

# %%
deсember = df.drop(df.columns[[0, 2, 3, 4, 7, 8, 9, 11, 12, 13, 14, 15, 16, 17, 18, 20, 22, 23, 24, 25, 26, 27, 28,29]], axis = 1)\
            .loc[(df['Улица'] == 'Транзитная') & (df['Номер дома'] == 6)]\
            .rename(columns = {'Отчетный период': 'Отчетный_период', 'Улица':'Улица', 'Номер дома':'Номер_дома', 'Квартира':'Квартира',
                              'Начислено кВт*ч':'Начислено_кВт*ч'})
deсember.head(5)
# Out:
#       Отчетный_период       Улица  Номер_дома  Квартира  \
# 3511           202312  Транзитная           6        18
# 3512           202312  Транзитная           6        18
# 3513           202312  Транзитная           6        46
# 3514           202312  Транзитная           6        46
# 3515           202312  Транзитная           6        13
#
#      Способ формирования начислений  Начислено_кВт*ч
# 3511                             ФП            277.0
# 3512                            NaN            277.0
# 3513                             РО            109.0
# 3514                            NaN            109.0
# 3515                             ФП            100.0

# %%
analiz = pd.concat([oktubre, septiembre, agosto, julio, junio, may, april, march, januyry, february, november, deсember], ignore_index=True)
analiz
# Out:
#       Отчетный_период       Улица  Номер_дома  Квартира  \
# 0              202310  Транзитная           6        18
# 1              202310  Транзитная           6        18
# 2              202310  Транзитная           6        46
# 3              202310  Транзитная           6        46
# 4              202310  Транзитная           6        13
# ...               ...         ...         ...       ...
# 1307           202312  Транзитная           6        48
# 1308           202312  Транзитная           6        34
# 1309           202312  Транзитная           6        34
# 1310           202312  Транзитная           6        32
# 1311           202312  Транзитная           6        32
#
#      Способ формирования начислений  Начислено_кВт*ч
# 0                                ФП            194.0
# 1                               NaN            194.0
# 2                                ФП            109.0
# 3                               NaN            109.0
# ...

# %%
analiz['Отчетный_период'].replace({202307: '07 июль2024', 202308: '08 август2024', 202309:'09 сентябрь2024', 202301:'01 январь2024', 202302:'02 февраль2024',
                                   202310:'10 октябрь2024', 202306:'06 июнь2024', 202304:'04 апрель2024', 202305:'05 май2024', '01.03.2024':'03 март2024',
                                   202311: '11 ноябрь2024', 202312: '12 декабрь2024'}, inplace=True)
analiz.head(5)
# Out:
#   Отчетный_период       Улица  Номер_дома  Квартира  \
# 0  10 октябрь2024  Транзитная           6        18
# 1  10 октябрь2024  Транзитная           6        18
# 2  10 октябрь2024  Транзитная           6        46
# 3  10 октябрь2024  Транзитная           6        46
# 4  10 октябрь2024  Транзитная           6        13
#
#   Способ формирования начислений  Начислено_кВт*ч
# 0                             ФП            194.0
# 1                            NaN            194.0
# 2                             ФП            109.0
# 3                            NaN            109.0
# 4                             ФП            150.0

# %%
analiz = analiz.dropna()
analiz
# Out:
#      Отчетный_период       Улица  Номер_дома  Квартира  \
# 0     10 октябрь2024  Транзитная           6        18
# 2     10 октябрь2024  Транзитная           6        46
# 4     10 октябрь2024  Транзитная           6        13
# 6     10 октябрь2024  Транзитная           6        10
# 8     10 октябрь2024  Транзитная           6        10
# ...              ...         ...         ...       ...
# 1302  12 декабрь2024  Транзитная           6        46
# 1304  12 декабрь2024  Транзитная           6        47
# 1306  12 декабрь2024  Транзитная           6        48
# 1308  12 декабрь2024  Транзитная           6        34
# 1310  12 декабрь2024  Транзитная           6        32
#
#      Способ формирования начислений  Начислено_кВт*ч
# 0                                ФП            194.0
# 2                                ФП            109.0
# 4                                ФП            150.0
# 6                                ТП            202.0
# ...

# %%
analiz =analiz.rename(columns = {'Способ формирования начислений':'Способ_формирования_начислений'})
analiz
# Out:
#      Отчетный_период       Улица  Номер_дома  Квартира  \
# 0     10 октябрь2024  Транзитная           6        18
# 2     10 октябрь2024  Транзитная           6        46
# 4     10 октябрь2024  Транзитная           6        13
# 6     10 октябрь2024  Транзитная           6        10
# 8     10 октябрь2024  Транзитная           6        10
# ...              ...         ...         ...       ...
# 1302  12 декабрь2024  Транзитная           6        46
# 1304  12 декабрь2024  Транзитная           6        47
# 1306  12 декабрь2024  Транзитная           6        48
# 1308  12 декабрь2024  Транзитная           6        34
# 1310  12 декабрь2024  Транзитная           6        32
#
#      Способ_формирования_начислений  Начислено_кВт*ч
# 0                                ФП            194.0
# 2                                ФП            109.0
# 4                                ФП            150.0
# 6                                ТП            202.0
# ...

# %%
analiz['Способ_формирования_начислений'].replace({'ФП':'Фактический объем', 'РО':'Расчетный объем',
                                   'КД':'Коррекция начислений', 'ТП':'Бесприборный учет'}, inplace=True)
analiz.head(5)
# Out:
#   Отчетный_период       Улица  Номер_дома  Квартира  \
# 0  10 октябрь2024  Транзитная           6        18
# 2  10 октябрь2024  Транзитная           6        46
# 4  10 октябрь2024  Транзитная           6        13
# 6  10 октябрь2024  Транзитная           6        10
# 8  10 октябрь2024  Транзитная           6        10
#
#   Способ_формирования_начислений  Начислено_кВт*ч
# 0              Фактический объем            194.0
# 2              Фактический объем            109.0
# 4              Фактический объем            150.0
# 6              Бесприборный учет            202.0
# 8              Фактический объем              6.0

# %%
analiz['Квартира'] = analiz['Квартира'].astype(int)

# %%
analiz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 661 entries, 0 to 1310
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Отчетный_период                 661 non-null    object
#  1   Улица                           661 non-null    object
#  2   Номер_дома                      661 non-null    int64
#  3   Квартира                        661 non-null    int64
#  4   Способ_формирования_начислений  661 non-null    object
#  5   Начислено_кВт*ч                 661 non-null    float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 36.1+ KB

# %%
analiz1 = analiz.pivot_table(index=['Квартира', 'Способ_формирования_начислений'], columns=['Отчетный_период'], values='Начислено_кВт*ч',
                             aggfunc="min", fill_value='-')
analiz1
# Out:
# Отчетный_период                         202303 01 январь2024 02 февраль2024  \
# Квартира Способ_формирования_начислений
# 1        Расчетный объем                     -             -              -
#          Фактический объем                65.0         152.0          125.0
# 2        Фактический объем               200.0         203.0          202.0
# 3        Коррекция начислений                -             -              -
#          Расчетный объем                     -             -              -
# ...                                        ...           ...            ...
# 45       Фактический объем                   -         290.0              -
# 46       Расчетный объем                  91.0             -           83.0
#          Фактический объем                   -         103.0              -
# 47       Фактический объем               280.0         536.0          498.0
# 48       Расчетный объем                 523.0         523.0          473.0
#
# ...

# %%
analiz1.to_html('analiz1.html')

# %%
analiz.groupby(['Начислено_кВт*ч']).min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, how, values, ndim, alt)
#    1941         try:
# -> 1942             res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943         except Exception as err:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     863
# --> 864         result = self._aggregate_series_pure_python(obj, func)
#     865
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#     884         for i, group in enumerate(splitter):
# --> 885             res = func(group)
#     886             res = extract_result(res)
#
# ...
